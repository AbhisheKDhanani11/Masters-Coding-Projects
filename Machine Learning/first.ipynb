# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#       pclass  survived                                             name
# 0          1         1                    Allen, Miss. Elisabeth Walton  \
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat
# 0     female      29      0      0   24160  211.3375       B5        S    2  \
# 1       male  0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female       2      1      2  113781    151.55  C22 C26        S    ?
# 3       male      30      1      2  113781    151.55  C22 C26        S    ?
# 4     female      25      1      2  113781    151.55  C22 C26        S    ?
# ...      ...     ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female    14.5      1      0    2665   14.4542        ?        C    ?
# 1305  female       ?      1      0    2665   14.4542        ?        C    ?
# 1306    male    26.5      0      0    2656     7.225        ?        C    ?
# 1307    male      27      0      0    2670     7.225        ?        C    ?
# 1308    male      29      0      0  315082     7.875        ?        S    ?
#
#      body                        home.dest
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
# [1309 rows x 14 columns]

# %%
print(df.isnull().sum().sum())
df
# Out:
# 0
#       pclass  survived                                             name
# 0          1         1                    Allen, Miss. Elisabeth Walton  \
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat
# 0     female      29      0      0   24160  211.3375       B5        S    2  \
# 1       male  0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female       2      1      2  113781    151.55  C22 C26        S    ?
# 3       male      30      1      2  113781    151.55  C22 C26        S    ?
# 4     female      25      1      2  113781    151.55  C22 C26        S    ?
# ...      ...     ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female    14.5      1      0    2665   14.4542        ?        C    ?
# 1305  female       ?      1      0    2665   14.4542        ?        C    ?
# 1306    male    26.5      0      0    2656     7.225        ?        C    ?
# 1307    male      27      0      0    2670     7.225        ?        C    ?
# 1308    male      29      0      0  315082     7.875        ?        S    ?
#
#      body                        home.dest
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
# [1309 rows x 14 columns]

# %%
df['age2'] = df['age'].replace(("?"), (np.nan))
df[['name', 'age', 'age2']].sample(100)
# Out:
#                                                    name   age  age2
# 1035  Moubarek, Master. Halim Gonios ('William George')     ?   NaN
# 791                                Elias, Mr. Joseph Jr    17    17
# 564                           Smith, Miss. Marion Elsie    40    40
# 717                         Chronopoulos, Mr. Demetrios    18    18
# 659                      Baclini, Miss. Marie Catherine     5     5
# ...                                                 ...   ...   ...
# 100        Duff Gordon, Sir. Cosmo Edmund ('Mr Morgan')    49    49
# 671                        Berglund, Mr. Karl Ivar Sven    22    22
# 1210                                 Skoog, Mr. Wilhelm    40    40
# 250                          Ryerson, Miss. Emily Borie    18    18
# 1171                        Sage, Master. William Henry  14.5  14.5
#
# [100 rows x 3 columns]

# %%
df2 = df[df['age2'].isnull()==False]
df2
# Out:
#       pclass  survived                                             name
# 0          1         1                    Allen, Miss. Elisabeth Walton  \
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1301       3         0                             Youseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat
# 0     female      29      0      0   24160  211.3375       B5        S    2  \
# 1       male  0.9167      1      2  113781    151.55  C22 C26        S   11
# 2     female       2      1      2  113781    151.55  C22 C26        S    ?
# 3       male      30      1      2  113781    151.55  C22 C26        S    ?
# 4     female      25      1      2  113781    151.55  C22 C26        S    ?
# ...      ...     ...    ...    ...     ...       ...      ...      ...  ...
# 1301    male    45.5      0      0    2628     7.225        ?        C    ?
# 1304  female    14.5      1      0    2665   14.4542        ?        C    ?
# 1306    male    26.5      0      0    2656     7.225        ?        C    ?
# 1307    male      27      0      0    2670     7.225        ?        C    ?
# 1308    male      29      0      0  315082     7.875        ?        S    ?
#
#      body                        home.dest    age2           province
# 0       ?                     St Louis, MO      29                 MO  \
# 1       ?  Montreal, PQ / Chesterville, ON  0.9167  PQ / Chesterville
# 2       ?  Montreal, PQ / Chesterville, ON       2  PQ / Chesterville
# 3     135  Montreal, PQ / Chesterville, ON      30  PQ / Chesterville
# 4       ?  Montreal, PQ / Chesterville, ON      25  PQ / Chesterville
# ...   ...                              ...     ...                ...
# 1301  312                                ?    45.5               None
# 1304  328                                ?    14.5               None
# 1306  304                                ?    26.5               None
# 1307    ?                                ?      27               None
# 1308    ?                                ?      29               None
#
#           FName
# 0         Allen
# 1       Allison
# 2       Allison
# 3       Allison
# 4       Allison
# ...         ...
# 1301    Youseff
# 1304     Zabour
# 1306   Zakarian
# 1307   Zakarian
# 1308  Zimmerman
#
# [1046 rows x 17 columns]

# %%
def get_province(dest):
    if dest and ',' in dest:
        return dest.split(',')[1].strip()
    else:
        return None
    
get_province(None)
get_province('?')
df['province'] = df['home.dest'].apply(get_province)
df['province'].value_counts()
# Out:
# province
# NY                            127
# England                        30
# NJ                             29
# MA                             27
# PA                             26
#                              ...
# Cornwall                        1
# Switzerland / Central City      1
# Cornwall / Houghton             1
# Japan                           1
# Belgium / Stanton               1
# Name: count, Length: 174, dtype: int64

# %%
def get_Fname(name):
    if name and ',' in name:
        return name.split(',')[0].strip()
    else:
        None
        
df['FName'] = df['name'].apply(get_Fname)
df['FName'].value_counts()
# Out:
# FName
# Andersson    11
# Sage         11
# Goodwin       8
# Asplund       8
# Davies        7
#              ..
# Myles         1
# Nesson        1
# Nicholls      1
# Norman        1
# Zimmerman     1
# Name: count, Length: 875, dtype: int64

# %%
import seaborn as sns

# %%
sns.boxplot(df['age2'])
# Out:
# <Axes: ylabel='age2'>

# %%
pd.crosstab(df['pclass'], df['survived'], normalize='index')
# Out:
# survived         0         1
# pclass
# 1         0.380805  0.619195
# 2         0.570397  0.429603
# 3         0.744711  0.255289

# %%
pd.crosstab(df['sex'], df['survived'], normalize='index')
# Out:
# survived         0         1
# sex
# female    0.272532  0.727468
# male      0.809015  0.190985
